# %%
# Please execute this cell first to have the headers ready
# Some websites need to see some browser headers to allow scripts to scrape them.
# Such headers can be found on Google and then be used in requests.get() as we do in this notebook

headers = {
    'pragma': 'no-cache',
    'cache-control': 'no-cache',
    'dnt': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
}

# %%
#Get the first page to extract page numbers
import requests, re
from bs4 import BeautifulSoup

r=requests.get("https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/", headers=headers) # We use the headers here
c=r.content

soup=BeautifulSoup(c,"html.parser")

all=soup.find_all("div",{"class":"propertyRow"})

all[0].find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")

page_nr=soup.find_all("a",{"class":"Page"})[-1].text
print(page_nr,"number of pages were found")
# Out:
# 3 number of pages were found

# %%
l=[]
base_url="https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
for page in range(0,int(page_nr)*10,10):
    print( )
    r=requests.get(base_url+str(page)+".html", headers=headers)
    c=r.content
    #c=r.json()["list"]
    soup=BeautifulSoup(c,"html.parser")
    all=soup.find_all("div",{"class":"propertyRow"})
    for item in all:
        d={}
        d["Address"]=item.find_all("span",{"class","propAddressCollapse"})[0].text
        try:
            d["Locality"]=item.find_all("span",{"class","propAddressCollapse"})[1].text
        except:
            d["Locality"]=None
        d["Price"]=item.find("h4",{"class","propPrice"}).text.replace("\n","").replace(" ","")
        try:
            d["Beds"]=item.find("span",{"class","infoBed"}).find("b").text
        except:
            d["Beds"]=None
    
        try:
            d["Area"]=item.find("span",{"class","infoSqFt"}).find("b").text
        except:
            d["Area"]=None
    
        try:
            d["Full Baths"]=item.find("span",{"class","infoValueFullBath"}).find("b").text
        except:
            d["Full Baths"]=None

        try:
            d["Half Baths"]=item.find("span",{"class","infoValueHalfBath"}).find("b").text
        except:
            d["Half Baths"]=None
        for column_group in item.find_all("div",{"class":"columnGroup"}):
            for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}),column_group.find_all("span",{"class":"featureName"})):
                if "Lot Size" in feature_group.text:
                    print(feature_name.text)
                    d["Lot Size"]=feature_name.text
        l.append(d)
# Out:
# 0.21 Acres
# Under 1/2 Acre,
# Under 1/2 Acre,
# 0.27 Acres
# Under 1/2 Acre,
# Under 1/2 Acre,
# Under 1/2 Acre,
# 2.02 Acres
#
#
# 5 Acres
# 0.7 Acres
# 3 Acres
# Under 1/2 Acre
# 2.35 Acres
# 2.05 Acres
# 0.73 Acres
# 0.31 Acres

# %%
l
# Out:
# [{'Address': '0 Gateway',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$725,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': '1003 Winchester Blvd.',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$452,900',
#   'Beds': '4',
#   'Area': None,
#   'Full Baths': '4',
#   'Half Baths': None,
#   'Lot Size': '0.21 Acres'},
#  {'Address': '600 Talladega',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$396,900',
#   'Beds': '5',
#   'Area': '3,154',
#   'Full Baths': '3',
#   'Half Baths': None},
#  {'Address': '3239 Spearhead Way',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$389,900',
#   'Beds': '4',
#   'Area': '3,076',
#   'Full Baths': '3',
#   'Half Baths': '1',
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '522 Emerald Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$254,000',
#   'Beds': '3',
#   'Area': '1,172',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': "1302 Veteran's Drive",
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$252,900',
#   'Beds': '4',
#   'Area': '1,932',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': '0.27 Acres'},
#  {'Address': '1021 Cypress Cir',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$210,000',
#   'Beds': '4',
#   'Area': '1,676',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '913 Madison Dr',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$209,000',
#   'Beds': '3',
#   'Area': '1,344',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '1344 Teton Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$199,900',
#   'Beds': '3',
#   'Area': '1,920',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Address': '4 Minnies Lane',
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$196,900',
#   'Beds': '3',
#   'Area': '1,664',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Lot Size': '2.02 Acres'},
#  {'Address': '9339 Sd 26900',
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$1,700,000',
#   'Beds': None,
#   'Area': '2,560',
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': 'RR674P13 Hwy 377',
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$1,100,000',
#   'Beds': None,
#   'Area': '2,000',
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': '0 Hwy 41',
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$1,080,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': '9339 Sd 26900',
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$908,350',
#   'Beds': None,
#   'Area': '2,560',
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': 'CR450 Hwy 377',
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$905,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': 'Cr 240 Cr 240',
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$695,000',
#   'Beds': None,
#   'Area': '1,398',
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': 'RR674 Hwy 377',
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$605,000',
#   'Beds': None,
#   'Area': '1,738',
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': '9770a Sd 26900',
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$559,805',
#   'Beds': None,
#   'Area': '1,080',
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': 'Lot17 CR 2630',
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$504,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': 'Tr12,16 CR 520',
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$410,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': '32575 S Shadow Mountain Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$299,900',
#   'Beds': '3',
#   'Area': '2,318',
#   'Full Baths': '2',
#   'Half Baths': None},
#  {'Address': '32750 S Shangrila Drive',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$167,500',
#   'Beds': '3',
#   'Area': '2,120',
#   'Full Baths': '2',
#   'Half Baths': None},
#  {'Address': '0000 Black Canyon Highway',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$150,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Lot Size': '5 Acres'},
#  {'Address': '34775 S CHOLLA Drive',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$129,500',
#   'Beds': '3',
#   'Area': '1,220',
#   'Full Baths': '2',
#   'Half Baths': None},
#  {'Address': '33403 S. HA-WA-SI TERRACE',
#   'Locality': 'BLACK CANYON CITY, AZ 85324',
#   'Price': '$129,000',
#   'Beds': '4',
#   'Area': '2,000',
#   'Full Baths': '2',
#   'Half Baths': None},
#  {'Address': '34263 S Bertha Street',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$80,000',
#   'Beds': '5',
#   'Area': '2,260',
#   'Full Baths': '2',
#   'Half Baths': None},
#  {'Address': '33160 S Canyon Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$77,900',
#   'Beds': '3',
#   'Area': '1,248',
#   'Full Baths': '2',
#   'Half Baths': None},
#  {'Address': '19421 E Todd Evans Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$70,500',
#   'Beds': '3',
#   'Area': '1,404',
#   'Full Baths': '2',
#   'Half Baths': None},
#  {'Address': '18688 E AGUA Vista',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$70,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Lot Size': '0.7 Acres'},
#  {'Address': '50600 N Old Black Canyon Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$67,500',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Lot Size': '3 Acres'},
#  {'Address': '20101 E SQUAW VALLEY Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$54,900',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None},
#  {'Address': '33259 S Canyon Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$45,600',
#   'Beds': '3',
#   'Area': '1,056',
#   'Full Baths': '1',
#   'Half Baths': None},
#  {'Address': '34558 S ROADRUNNER RD',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$40,000',
#   'Beds': '2',
#   'Area': '784',
#   'Full Baths': '1',
#   'Half Baths': None,
#   'Lot Size': 'Under 1/2 Acre'},
#  {'Address': '19260 E Scenic Loop Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$30,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Lot Size': '2.35 Acres'},
#  {'Address': '19000 E MAREN Avenue',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$29,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Lot Size': '2.05 Acres'},
#  {'Address': '19350 E SAGUARO Drive',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$28,995',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Lot Size': '0.73 Acres'},
#  {'Address': '20650 E Amethyst Place',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$15,000',
#   'Beds': None,
#   'Area': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Lot Size': '0.31 Acres'}]

# %%
import pandas
df=pandas.DataFrame(l)

# %%
df
# Out:
#                           Address                     Locality       Price  \
# 0                       0 Gateway       Rock Springs, WY 82901    $725,000
# 1           1003 Winchester Blvd.       Rock Springs, WY 82901    $452,900
# 2                   600 Talladega       Rock Springs, WY 82901    $396,900
# 3              3239 Spearhead Way       Rock Springs, WY 82901    $389,900
# 4              522 Emerald Street       Rock Springs, WY 82901    $254,000
# 5            1302 Veteran's Drive       Rock Springs, WY 82901    $252,900
# 6                1021 Cypress Cir       Rock Springs, WY 82901    $210,000
# 7                  913 Madison Dr       Rock Springs, WY 82901    $209,000
# 8               1344 Teton Street       Rock Springs, WY 82901    $199,900
# 9                  4 Minnies Lane       Rock Springs, WY 82901    $196,900
# 10                  9339 Sd 26900        Rocksprings, TX 78880  $1,700,000
# 11               RR674P13 Hwy 377        Rocksprings, TX 78880  $1,100,000
# 12                       0 Hwy 41        Rocksprings, TX 78880  $1,080,000
# 13                  9339 Sd 26900        Rocksprings, TX 78880    $908,350
# 14                  CR450 Hwy 377        Rocksprings, TX 78880    $905,000
# 15                  Cr 240 Cr 240        Rocksprings, TX 78880    $695,000
# 16                  RR674 Hwy 377        Rocksprings, TX 78880    $605,000
# 17                 9770a Sd 26900        Rocksprings, TX 78880    $559,805
# 18                  Lot17 CR 2630        Rocksprings, TX 78880    $504,000
# 19                 Tr12,16 CR 520        Rocksprings, TX 78880    $410,000
# 20   32575 S Shadow Mountain Road  Black Canyon City, AZ 85324    $299,900
# 21        32750 S Shangrila Drive  Black Canyon City, AZ 85324    $167,500
# 22      0000 Black Canyon Highway  Black Canyon City, AZ 85324    $150,000
# 23           34775 S CHOLLA Drive  Black Canyon City, AZ 85324    $129,500
# 24      33403 S. HA-WA-SI TERRACE  BLACK CANYON CITY, AZ 85324    $129,000
# 25          34263 S Bertha Street  Black Canyon City, AZ 85324     $80,000
# 26            33160 S Canyon Road  Black Canyon City, AZ 85324     $77,900
# 27        19421 E Todd Evans Road  Black Canyon City, AZ 85324     $70,500
# 28             18688 E AGUA Vista  Black Canyon City, AZ 85324     $70,000
# 29  50600 N Old Black Canyon Road  Black Canyon City, AZ 85324     $67,500
# 30      20101 E SQUAW VALLEY Road  Black Canyon City, AZ 85324     $54,900
# 31            33259 S Canyon Road  Black Canyon City, AZ 85324     $45,600
# 32          34558 S ROADRUNNER RD  Black Canyon City, AZ 85324     $40,000
# 33       19260 E Scenic Loop Road  Black Canyon City, AZ 85324     $30,000
# 34           19000 E MAREN Avenue  Black Canyon City, AZ 85324     $29,000
# 35          19350 E SAGUARO Drive  Black Canyon City, AZ 85324     $28,995
# 36         20650 E Amethyst Place  Black Canyon City, AZ 85324     $15,000
#
#     Beds   Area Full Baths Half Baths          Lot Size
# 0   None   None       None       None               NaN
# 1      4   None          4       None        0.21 Acres
# 2      5  3,154          3       None               NaN
# 3      4  3,076          3          1  Under 1/2 Acre,
# 4      3  1,172          3       None  Under 1/2 Acre,
# 5      4  1,932          2       None        0.27 Acres
# 6      4  1,676          3       None  Under 1/2 Acre,
# 7      3  1,344          2       None  Under 1/2 Acre,
# 8      3  1,920          2       None  Under 1/2 Acre,
# 9      3  1,664          2       None        2.02 Acres
# 10  None  2,560       None       None               NaN
# 11  None  2,000       None       None               NaN
# 12  None   None       None       None               NaN
# 13  None  2,560       None       None               NaN
# 14  None   None       None       None               NaN
# 15  None  1,398       None       None               NaN
# 16  None  1,738       None       None               NaN
# 17  None  1,080       None       None               NaN
# 18  None   None       None       None               NaN
# 19  None   None       None       None               NaN
# 20     3  2,318          2       None               NaN
# 21     3  2,120          2       None               NaN
# 22  None   None       None       None           5 Acres
# 23     3  1,220          2       None               NaN
# 24     4  2,000          2       None               NaN
# 25     5  2,260          2       None               NaN
# 26     3  1,248          2       None               NaN
# 27     3  1,404          2       None               NaN
# 28  None   None       None       None         0.7 Acres
# 29  None   None       None       None           3 Acres
# 30  None   None       None       None               NaN
# 31     3  1,056          1       None               NaN
# 32     2    784          1       None    Under 1/2 Acre
# 33  None   None       None       None        2.35 Acres
# 34  None   None       None       None        2.05 Acres
# 35  None   None       None       None        0.73 Acres
# 36  None   None       None       None        0.31 Acres

# %%
df.to_csv("Output.csv")

# %%
import requests, re
from bs4 import BeautifulSoup

r=requests.get("https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/", headers=headers)
c=r.content

soup=BeautifulSoup(c,"html.parser")

all=soup.find_all("div",{"class":"propertyRow"})

all[0].find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")

page_nr=soup.find_all("a",{"class":"Page"})[-1].text
print(page_nr,"number of pages were found")

base_url="https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
for page in range(0,int(page_nr)*10,10):
    print( )
    r=requests.get(base_url+str(page)+".html")
    c=r.content
    #c=r.json()["list"]
    soup=BeautifulSoup(c,"html.parser")
    all=soup.find_all("div",{"class":"propertyRow"})
    
print(all)
# Out:
# 3 number of pages were found
#
#
#
# [<div class="propertyRow" id="propertyRowREN007760751" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand REN to view details'); document.location.href='/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751';" style="width: 1114px;">
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyREN007760751">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751"><img class="lazyLoad" rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/0?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/0"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $299,900
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="32575 S Shadow Mountain Road">32575 S Shadow Mountain Road</span>
# <span class="propAddressCollapse">Black Canyon City, AZ 85324</span>
# <input name="shortCurrency" type="hidden" value="$299K"/>
# <input name="proplongitude" type="hidden" value="-112.120476"/>
# <input name="proplatitude" type="hidden" value="34.090745"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# <span class="infoBed"><b>3</b> Beds</span>
# <span class="infoSqFt"><b>2,318</b> Sq. Ft</span>
# </div>
# <div class="infoLine2">
# <span class="infoValueFullBath"><b>2</b> Full Baths</span>
# </div>
# </div>
# <div class="secondaryHeader">
#          Courtesy Of RE/MAX Excalibur Realty
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751">
# <span class="IconPropertyPhotos16"></span>
#
#       18
#       Images
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('REN007760751', '#propertyRowREN007760751');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('REN007760751', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('REN007760751', '#propertyREN007760751');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('REN007760751', '#propertyREN007760751');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN007760751', '#propertyRowREN007760751');c21Helpers.stopEvent(event);" title="32575 S Shadow Mountain Road, Black Canyon City, AZ 85324 | $299,900">
# <span class="IconActionUnhide16"></span>
# </a>
# <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN007760751', '#propertyRowREN007760751');c21Helpers.stopEvent(event);" title="32575 S Shadow Mountain Road, Black Canyon City, AZ 85324 | $299,900">
#       Unhide Property: 32575 S Shadow Mountain Road, Black Canyon City, AZ 85324 | $299,900
#    </a>
# </div>
# <div class="clear"></div>
# </div>
# <div class="propertyDetails">
# <div class="invisibleFloat"></div>
# <div class="propertyDetailPhotos" id="propertyRowREN007760751propertyDetailPhotos">
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=0" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/0?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/0"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=1" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/2?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/2"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=2" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/3?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/3"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=3" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/4?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/4"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=4" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/5?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/5"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=5" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/6?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/6"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=6" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/7?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/7"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=7" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/8?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/8"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=8" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/9?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/9"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=9" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/10?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/10"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=10" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/11?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/11"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=11" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/12?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/12"/></a>
# </div>
# </div>
# <div class="photoFlow last">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=12" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/13?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/13"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751?g=13" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4857876/14?lm=20121204T023923" src="./LCWYROCKSPRINGS2_files/14"/></a>
# </div>
# <div class="viewMorePhotosContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751" onclick="Track.doEvent('Hybrid Mapping', 'Property List View', 'View More Photos');" title="View more photos">View<br/>More</a>
# </div>
# </div>
# <div class="propertyMLS">MLS#
#
#                         4857876
#
#                   </div>
# </div>
# <div class="propertyDescription" id="propertyRowREN007760751propertyDescription">
# <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
# <div class="propertyDescCollapse collapsed" expandlink="/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751" id="propertyRowREN007760751propertyDescCollapse"> Entry opens to lovely frml liv &amp; din rooms. Inviting kit includes break bar, walk in pantry &amp; custom tiled counter tops. Breakfast nook w/large wet bar &amp; opens to kit &amp; fam rm. Family rm retreat w/cozy fireplace. Convenient inside laundry rm w/sink. Split floor plan w/3 generous BD's <a href="http://web.archive.org/property/32575-s-shadow-mountain-road-black-canyon-city-az-85324-REN007760751" title="&amp; 2 full BA's. Mstr suite w/French door exit to balcony. Mstr BA w/private exit to deck &amp; cstm steam shower. Features include cstm ceramic tile flooring, solid wood cabinetry, central vacuum &amp; large Pella viewing windows. Relaxing above ground heated spa. 2CG w/elec opener. RV parking w/water, septic &amp; elec hook-up. Additional 9'x23' storage area underneath house. 2,500 gal water tank w/on demand pump. Premium 4.63 acre lot in Black Canyon City offers endless, stunning views &amp; borders Aqua Fria Monument.  ">…Read More</a></div><span style="display: none">&amp; 2 full BA's. Mstr suite w/French door exit to balcony. Mstr BA w/private exit to deck &amp; cstm steam shower. Features include cstm ceramic tile flooring, solid wood cabinetry, central vacuum &amp; large Pella viewing windows. Relaxing above ground heated spa. 2CG w/elec opener. RV parking w/water, septic &amp; elec hook-up. Additional 9'x23' storage area underneath house. 2,500 gal water tank w/on demand pump. Premium 4.63 acre lot in Black Canyon City offers endless, stunning views &amp; borders Aqua Fria Monument.  <a href="javascript: void(0)">&lt; less</a></span>
# </div>
# <div class="propertyFeatures" id="propertyRowREN007760751propertyFeatures">
# <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
# <span class="featureGroup">Age: </span><span class="featureName">11-20 Years Old</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Amenities: </span><span class="featureName">Deck, </span><span class="featureName">Patio, </span><span class="featureName">Vaulted Ceiling, </span><span class="featureName">RV Parking, </span><span class="featureName">Ceiling Fan</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Appliances: </span><span class="featureName">Dishwasher, </span><span class="featureName">Oven, </span><span class="featureName">Vacuum System</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Architecture Style: </span><span class="featureName">Other</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Exterior Type: </span><span class="featureName">Stucco</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Fireplace: </span><span class="featureName">Fireplace</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Floor Covering: </span><span class="featureName">Carpet, </span><span class="featureName">Tile</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Heating Fuel: </span><span class="featureName">Electric</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Parking Type: </span><span class="featureName">Open, </span><span class="featureName">RV</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Roof Type: </span><span class="featureName">Tile</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Rooms: </span><span class="featureName">Bedroom, </span><span class="featureName">Dining Room, </span><span class="featureName">Family Room, </span><span class="featureName">Full Bath, </span><span class="featureName">Kitchen, </span><span class="featureName">Living Room</span>
# </div><div class="columnGroup">
# <span class="featureGroup">View Type: </span><span class="featureName">Mountain</span>
# </div></div></div>
# </div>
# </div>, <div class="propertyRow" id="propertyRowCBR19168329" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand CBR to view details'); document.location.href='/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329';" style="width: 1114px;">
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyCBR19168329">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329"><img class="lazyLoad" rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_2.jpg" src="./LCWYROCKSPRINGS2_files/imageloading.gif"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $167,500
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="32750 S Shangrila Drive">32750 S Shangrila Drive</span>
# <span class="propAddressCollapse">Black Canyon City, AZ 85324</span>
# <input name="shortCurrency" type="hidden" value="$167K"/>
# <input name="proplongitude" type="hidden" value="-112.118"/>
# <input name="proplatitude" type="hidden" value="34.0882"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# <span class="infoBed"><b>3</b> Beds</span>
# <span class="infoSqFt"><b>2,120</b> Sq. Ft</span>
# </div>
# <div class="infoLine2">
# <span class="infoValueFullBath"><b>2</b> Full Baths</span>
# </div>
# </div>
# <div class="secondaryHeader">
#          Courtesy Of Coldwell Banker Residential Brokerage
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329">
# <span class="IconPropertyPhotos16"></span>
#
#       25
#       Images
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('CBR19168329', '#propertyRowCBR19168329');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('CBR19168329', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('CBR19168329', '#propertyCBR19168329');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('CBR19168329', '#propertyCBR19168329');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('CBR19168329', '#propertyRowCBR19168329');c21Helpers.stopEvent(event);" title="32750 S Shangrila Drive, Black Canyon City, AZ 85324 | $167,500">
# <span class="IconActionUnhide16"></span>
# </a>
# <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('CBR19168329', '#propertyRowCBR19168329');c21Helpers.stopEvent(event);" title="32750 S Shangrila Drive, Black Canyon City, AZ 85324 | $167,500">
#       Unhide Property: 32750 S Shangrila Drive, Black Canyon City, AZ 85324 | $167,500
#    </a>
# </div>
# <div class="clear"></div>
# </div>
# <div class="propertyDetails">
# <div class="invisibleFloat"></div>
# <div class="propertyDetailPhotos" id="propertyRowCBR19168329propertyDetailPhotos">
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=0" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_2.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=1" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_3.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=2" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_4.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=3" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_5.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=4" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_6.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=5" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_7.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=6" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_8.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=7" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_9.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=8" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_10.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=9" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_11.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=10" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_12.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=11" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_13.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# </div>
# <div class="photoFlow last">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=12" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_14.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329?g=13" title=""><img rel="http://media2.nrtwebservices.com/Arizona/Properties/JPG_Main/857/1214857_15.jpg" src="./LCWYROCKSPRINGS2_files/loadingimage39x30.png"/></a>
# </div>
# <div class="viewMorePhotosContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/32750-s-shangrila-drive-black-canyon-city-az-85324-CBR19168329" onclick="Track.doEvent('Hybrid Mapping', 'Property List View', 'View More Photos');" title="View more photos">View<br/>More</a>
# </div>
# </div>
# <div class="propertyMLS">MLS#
#
#                         4773355
#
#                   </div>
# </div>
# <div class="propertyFeatures" id="propertyRowCBR19168329propertyFeatures">
# <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
# <span class="featureGroup">Area Description: </span><span class="featureName">Mountain</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Fireplace Count: </span><span class="featureName">2 Fireplaces</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Garage Description: </span><span class="featureName">No Garage</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Heating - Fuel Type: </span><span class="featureName">Electric</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Style: </span><span class="featureName">Other Style</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Water: </span><span class="featureName">Well</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Zoning: </span><span class="featureName">Ranch</span>
# </div></div></div>
# </div>
# </div>, <div class="propertyRow" id="propertyRowREN007479391" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand REN to view details'); document.location.href='/property/0000-black-canyon-highway-black-canyon-city-az-85324-REN007479391';" style="width: 1114px;">
# <div class="CenterLaneCardBg CardWrapper propertyCard hover" id="propertyREN007479391">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/0000-black-canyon-highway-black-canyon-city-az-85324-REN007479391"><img class="lazyLoad" rel="/images/icons/nopropertyfound.png" src="./LCWYROCKSPRINGS2_files/nopropertyfound.png"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $150,000
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="0000 Black Canyon Highway">0000 Black Canyon Highway</span>
# <span class="propAddressCollapse">Black Canyon City, AZ 85324</span>
# <input name="shortCurrency" type="hidden" value="$150K"/>
# <input name="proplongitude" type="hidden" value="-112.149503"/>
# <input name="proplatitude" type="hidden" value="34.038914"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# </div>
# <div class="infoLine2">
# </div>
# </div>
# <div class="secondaryHeader">
#          Courtesy Of Realty USA Southwest
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/0000-black-canyon-highway-black-canyon-city-az-85324-REN007479391">
# <span class="IconPropertyPhotos16"></span>
#
#       0
#       Images
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('REN007479391', '#propertyRowREN007479391');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('REN007479391', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('REN007479391', '#propertyREN007479391');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('REN007479391', '#propertyREN007479391');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN007479391', '#propertyRowREN007479391');c21Helpers.stopEvent(event);" title="0000 Black Canyon Highway, Black Canyon City, AZ 85324 | $150,000">
# <span class="IconActionUnhide16"></span>
# </a>
# <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN007479391', '#propertyRowREN007479391');c21Helpers.stopEvent(event);" title="0000 Black Canyon Highway, Black Canyon City, AZ 85324 | $150,000">
#       Unhide Property: 0000 Black Canyon Highway, Black Canyon City, AZ 85324 | $150,000
#    </a>
# </div>
# <div class="clear"></div>
# </div>
# <div class="propertyDetails">
# <div class="invisibleFloat"></div>
# <div class="propertyDetailPhotos" id="propertyRowREN007479391propertyDetailPhotos">
# <div class="propertyMLS">MLS#
#
#                         4841819
#
#                   </div>
# </div>
# <div class="propertyDescription" id="propertyRowREN007479391propertyDescription">
# <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
# <div class="propertyDescCollapse collapsed" expandlink="/property/0000-black-canyon-highway-black-canyon-city-az-85324-REN007479391" id="propertyRowREN007479391propertyDescCollapse"> Unique 5 acres near Rock Springs cafe/restaurant. This property has natural water spring with gold fish leaving year around.Can be zoned as commercial or split in 5 lots. Electric and well on a property. </div>
# </div>
# <div class="propertyFeatures" id="propertyRowREN007479391propertyFeatures">
# <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
# <span class="featureGroup">Architecture Style: </span><span class="featureName">Other</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Lot Size: </span><span class="featureName">5 Acres</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Roof Type: </span><span class="featureName">Unknown</span>
# </div><div class="columnGroup">
# <span class="featureGroup">View Type: </span><span class="featureName">Mountain</span>
# </div></div></div>
# </div>
# </div>, <div class="propertyRow" id="propertyRowREN000194076" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand REN to view details'); document.location.href='/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076';" style="width: 1114px;">
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyREN000194076">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076"><img class="lazyLoad" rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/0?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/0(1)"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $129,500
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="34775 S CHOLLA Drive">34775 S CHOLLA Drive</span>
# <span class="propAddressCollapse">Black Canyon City, AZ 85324</span>
# <input name="shortCurrency" type="hidden" value="$129K"/>
# <input name="proplongitude" type="hidden" value="-112.136073"/>
# <input name="proplatitude" type="hidden" value="34.065386"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# <span class="infoBed"><b>3</b> Beds</span>
# <span class="infoSqFt"><b>1,220</b> Sq. Ft</span>
# </div>
# <div class="infoLine2">
# <span class="infoValueFullBath"><b>2</b> Full Baths</span>
# </div>
# </div>
# <div class="secondaryHeader">
#          Courtesy Of D.L. Jones &amp; Associates Real Estate
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076">
# <span class="IconPropertyPhotos16"></span>
#
#       27
#       Images
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('REN000194076', '#propertyRowREN000194076');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('REN000194076', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('REN000194076', '#propertyREN000194076');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('REN000194076', '#propertyREN000194076');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN000194076', '#propertyRowREN000194076');c21Helpers.stopEvent(event);" title="34775 S CHOLLA Drive, Black Canyon City, AZ 85324 | $129,500">
# <span class="IconActionUnhide16"></span>
# </a>
# <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN000194076', '#propertyRowREN000194076');c21Helpers.stopEvent(event);" title="34775 S CHOLLA Drive, Black Canyon City, AZ 85324 | $129,500">
#       Unhide Property: 34775 S CHOLLA Drive, Black Canyon City, AZ 85324 | $129,500
#    </a>
# </div>
# <div class="clear"></div>
# </div>
# <div class="propertyDetails">
# <div class="invisibleFloat"></div>
# <div class="propertyDetailPhotos" id="propertyRowREN000194076propertyDetailPhotos">
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=0" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/0?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/0(1)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=1" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/2?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/2(1)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=2" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/3?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/3(1)"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=3" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/4?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/4(1)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=4" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/5?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/5(1)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=5" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/6?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/6(1)"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=6" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/7?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/7(1)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=7" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/8?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/8(1)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=8" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/9?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/9(1)"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=9" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/10?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/10(1)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=10" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/11?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/11(1)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=11" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/12?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/12(1)"/></a>
# </div>
# </div>
# <div class="photoFlow last">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=12" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/13?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/13(1)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076?g=13" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4686266/14?lm=20120125T152412" src="./LCWYROCKSPRINGS2_files/14(1)"/></a>
# </div>
# <div class="viewMorePhotosContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076" onclick="Track.doEvent('Hybrid Mapping', 'Property List View', 'View More Photos');" title="View more photos">View<br/>More</a>
# </div>
# </div>
# <div class="propertyMLS">MLS#
#
#                         4686266
#
#                   </div>
# </div>
# <div class="propertyDescription" id="propertyRowREN000194076propertyDescription">
# <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
# <div class="propertyDescCollapse collapsed" expandlink="/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076" id="propertyRowREN000194076propertyDescCollapse"> 360 Degree VIEWS!!! Come see the best views in Black Canyon City: Canyon Buttes, Bradshaw &amp; Mazatzalla Mountains! PRIVACY GALORE-This 1.64 acre property that backs to Nat'l Monument, has RV parking, a 2-car carport, a 10x13 workshop &amp; an immaculate manufactured home with a <a href="http://web.archive.org/property/34775-s-cholla-drive-black-canyon-city-az-85324-REN000194076" title="covered deck to take in the views! Home has been updated with wood flooring &amp; is in excellent condition. Front of home is fenced for pets. Separate sitting area to watch the sunsets over the Bradshaws. This spectacular lot will NOT disappoint!! SOLD AS-IS.  ">…Read More</a></div><span style="display: none">covered deck to take in the views! Home has been updated with wood flooring &amp; is in excellent condition. Front of home is fenced for pets. Separate sitting area to watch the sunsets over the Bradshaws. This spectacular lot will NOT disappoint!! SOLD AS-IS.  <a href="javascript: void(0)">&lt; less</a></span>
# </div>
# <div class="propertyFeatures" id="propertyRowREN000194076propertyFeatures">
# <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
# <span class="featureGroup">Age: </span><span class="featureName">21-30 Years Old</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Amenities: </span><span class="featureName">Deck, </span><span class="featureName">Patio, </span><span class="featureName">RV Parking, </span><span class="featureName">Ceiling Fan</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Appliances: </span><span class="featureName">Dishwasher, </span><span class="featureName">Oven, </span><span class="featureName">Refrigerator</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Architecture Style: </span><span class="featureName">Other</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Floor Covering: </span><span class="featureName">Carpet, </span><span class="featureName">Vinyl, </span><span class="featureName">Wood</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Heating Fuel: </span><span class="featureName">Electric</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Parking Type: </span><span class="featureName">RV</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Roof Type: </span><span class="featureName">Composition Shingle</span>
# </div></div><div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup">
# <span class="featureGroup">Rooms: </span><span class="featureName">Bedroom, </span><span class="featureName">Dining Room, </span><span class="featureName">Full Bath, </span><span class="featureName">Great Room, </span><span class="featureName">Kitchen, </span><span class="featureName">Workshop</span>
# </div><div class="columnGroup">
# <span class="featureGroup">View Type: </span><span class="featureName">Hills, </span><span class="featureName">Mountain</span>
# </div></div></div>
# </div>
# </div>, <div class="propertyRow" id="propertyRowC2137237139" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand C21 to view details'); document.location.href='/property/33403-s-ha-wa-si-terrace-black-canyon-city-az-85324-C2137237139';" style="width: 1114px;">
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyC2137237139">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/33403-s-ha-wa-si-terrace-black-canyon-city-az-85324-C2137237139"><img class="lazyLoad" rel="http://m.century21.com/1i6/np66xm9s868w42tzcxk77021x6i6" src="./LCWYROCKSPRINGS2_files/np66xm9s868w42tzcxk77021x6i6"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $129,000
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="33403 S. HA-WA-SI TERRACE">33403 S. HA-WA-SI TERRACE</span>
# <span class="propAddressCollapse">BLACK CANYON CITY, AZ 85324</span>
# <input name="shortCurrency" type="hidden" value="$129K"/>
# <input name="proplongitude" type="hidden" value="-112.127"/>
# <input name="proplatitude" type="hidden" value="34.0793"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# <span class="infoBed"><b>4</b> Beds</span>
# <span class="infoSqFt"><b>2,000</b> Sq. Ft</span>
# </div>
# <div class="infoLine2">
# <span class="infoValueFullBath"><b>2</b> Full Baths</span>
# </div>
# </div>
# <div class="secondaryHeader">
#          Listed By CENTURY 21 Desert Estates Realty
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/33403-s-ha-wa-si-terrace-black-canyon-city-az-85324-C2137237139">
# <span class="IconPropertyPhotos16"></span>
#
#       15
#       Images
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('C2137237139', '#propertyRowC2137237139');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('C2137237139', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('C2137237139', '#propertyC2137237139');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('C2137237139', '#propertyC2137237139');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('C2137237139', '#propertyRowC2137237139');c21Helpers.stopEvent(event);" title="33403 S. HA-WA-SI TERRACE, BLACK CANYON CITY, AZ 85324 | $129,000">
# <span class="IconActionUnhide16"></span>
# </a>
# ...
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyREN007584333">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333"><img class="lazyLoad" rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/0?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/0(11)"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $28,995
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="19350 E SAGUARO Drive">19350 E SAGUARO Drive</span>
# <span class="propAddressCollapse">Black Canyon City, AZ 85324</span>
# <input name="shortCurrency" type="hidden" value="$28K"/>
# <input name="proplongitude" type="hidden" value="-112.144819"/>
# <input name="proplatitude" type="hidden" value="34.073355"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# </div>
# <div class="infoLine2">
# </div>
# </div>
# <div class="secondaryHeader">
#          Courtesy Of Courtney Valleywide Properties
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333">
# <span class="IconPropertyPhotos16"></span>
#
#       6
#       Images
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('REN007584333', '#propertyRowREN007584333');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('REN007584333', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('REN007584333', '#propertyREN007584333');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('REN007584333', '#propertyREN007584333');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN007584333', '#propertyRowREN007584333');c21Helpers.stopEvent(event);" title="19350 E SAGUARO Drive, Black Canyon City, AZ 85324 | $28,995">
# <span class="IconActionUnhide16"></span>
# </a>
# <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN007584333', '#propertyRowREN007584333');c21Helpers.stopEvent(event);" title="19350 E SAGUARO Drive, Black Canyon City, AZ 85324 | $28,995">
#       Unhide Property: 19350 E SAGUARO Drive, Black Canyon City, AZ 85324 | $28,995
#    </a>
# </div>
# <div class="clear"></div>
# </div>
# <div class="propertyDetails">
# <div class="invisibleFloat"></div>
# <div class="propertyDetailPhotos" id="propertyRowREN007584333propertyDetailPhotos">
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333?g=0" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/0?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/0(11)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333?g=1" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/2?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/2(11)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333?g=2" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/3?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/3(11)"/></a>
# </div>
# </div>
# <div class="photoFlow last">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333?g=3" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/4?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/4(11)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333?g=4" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/5?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/5(11)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333?g=5" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4848089/6?lm=20121110T085749" src="./LCWYROCKSPRINGS2_files/6(11)"/></a>
# </div>
# </div>
# <div class="propertyMLS">MLS#
#
#                         4848089
#
#                   </div>
# </div>
# <div class="propertyDescription" id="propertyRowREN007584333propertyDescription">
# <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
# <div class="propertyDescCollapse collapsed" expandlink="/property/19350-e-saguaro-drive-black-canyon-city-az-85324-REN007584333" id="propertyRowREN007584333propertyDescCollapse"> This cul-de-sac lot is waiting for your site built or manufactured home! Great views of the surrounding hills and mountains. Level lot with utilities to property line. Paved road. The adjacent approx. 1/2 acre lot is also available for same price. </div>
# </div>
# <div class="propertyFeatures" id="propertyRowREN007584333propertyFeatures">
# <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
# <span class="featureGroup">Architecture Style: </span><span class="featureName">Other</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Lot Size: </span><span class="featureName">0.73 Acres</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Roof Type: </span><span class="featureName">Unknown</span>
# </div></div></div>
# </div>
# </div>, <div class="propertyRow" id="propertyRowREN004930163" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select a property with brand REN to view details'); document.location.href='/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163';" style="width: 1114px;">
# <div class="CenterLaneCardBg CardWrapper propertyCard" id="propertyREN004930163">
# <div class="CenterLaneCard propertyCard">
# <div class="CardThumb">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163"><img class="lazyLoad" rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/0?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/0(12)"/></a>
# </div>
# </div>
# <h4 class="propPrice">
#
#
#             $15,000
#
#
#
#       <span class="IconPropertyFavorite16"></span>
# </h4>
# <div class="CardDetails">
# <div class="primaryDetails">
# <span class="propAddressCollapse" title="20650 E Amethyst Place">20650 E Amethyst Place</span>
# <span class="propAddressCollapse">Black Canyon City, AZ 85324</span>
# <input name="shortCurrency" type="hidden" value="$15K"/>
# <input name="proplongitude" type="hidden" value="-112.122808"/>
# <input name="proplatitude" type="hidden" value="34.075862"/>
# </div>
# <div class="secondaryDetails">
# <div class="infoLine1">
# </div>
# <div class="infoLine2">
# </div>
# </div>
# <div class="secondaryHeader">
#          Courtesy Of Realty One Group
#
#       </div>
# </div>
# </div>
# <div class="CardActions">
# <a class="CardPhotoCount" href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163">
# <span class="IconPropertyPhotos16"></span>
#
#       9
#       Images
#    </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Hide a property'); myc21.hideProperty('REN004930163', '#propertyRowREN004930163');c21Helpers.stopEvent(event);" title="Hide">
# <span class="IconActionHide16"></span><b>Hide</b>
# </a>
# <a class="propertyAction" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Select Contact regarding property'); modalWindows.openPropertyContact('REN004930163', 'MainSearchProperty', '', 'PRP');c21Helpers.stopEvent(event);" title="Contact">
# <span class="IconActionContact16"></span><b>Contact</b>
# </a>
# <a class="propertyAction removeFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Remove a favorite property'); myc21.unfavoriteProperty('REN004930163', '#propertyREN004930163');c21Helpers.stopEvent(event);" title="Remove Favorite">
# <span class="IconActionRemoveFavorite16"></span>Remove Favorite
#          </a>
# <a class="propertyAction addFavorite" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Add a favorite property'); myc21.favoriteProperty('REN004930163', '#propertyREN004930163');c21Helpers.stopEvent(event);" title="Add to Favorites">
# <span class="IconActionAddFavorite16"></span><b>Add as Favorite</b>
# </a>
# </div>
# <div class="hiddenListItem">
# <a href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN004930163', '#propertyRowREN004930163');c21Helpers.stopEvent(event);" title="20650 E Amethyst Place, Black Canyon City, AZ 85324 | $15,000">
# <span class="IconActionUnhide16"></span>
# </a>
# <a class="propAddressHide" href="javascript:void(0);" onclick="Track.doEvent('Hybrid Mapping', 'Property Center Lane', 'Un-Hide a property');myc21.unhideProperty('REN004930163', '#propertyRowREN004930163');c21Helpers.stopEvent(event);" title="20650 E Amethyst Place, Black Canyon City, AZ 85324 | $15,000">
#       Unhide Property: 20650 E Amethyst Place, Black Canyon City, AZ 85324 | $15,000
#    </a>
# </div>
# <div class="clear"></div>
# </div>
# <div class="propertyDetails">
# <div class="invisibleFloat"></div>
# <div class="propertyDetailPhotos" id="propertyRowREN004930163propertyDetailPhotos">
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=0" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/0?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/0(12)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=1" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/2?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/2(12)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=2" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/3?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/3(12)"/></a>
# </div>
# </div>
# <div class="photoFlow">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=3" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/4?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/4(12)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=4" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/5?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/5(12)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=5" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/6?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/6(12)"/></a>
# </div>
# </div>
# <div class="photoFlow last">
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=6" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/7?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/7(10)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=7" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/8?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/8(8)"/></a>
# </div>
# <div class="landscapeThumbContainer">
# <a href="http://web.archive.org/web/20130107060952/http://www.century21.com/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163?g=8" title=""><img rel="http://www.century21.com/listhub/thumb/130x90/photos.listhub.net/ARMLSAZ/4749944/9?lm=20120427T023048" src="./LCWYROCKSPRINGS2_files/9(8)"/></a>
# </div>
# </div>
# <div class="propertyMLS">MLS#
#
#                         4749944
#
#                   </div>
# </div>
# <div class="propertyDescription" id="propertyRowREN004930163propertyDescription">
# <span class="propDescHeader">PROPERTY DESCRIPTION: </span>
# <div class="propertyDescCollapse collapsed" expandlink="/property/20650-e-amethyst-place-black-canyon-city-az-85324-REN004930163" id="propertyRowREN004930163propertyDescCollapse"> Great Views on this corner lot. Small town living and only 12 mins to Anthem. Lots of vegetation. </div>
# </div>
# <div class="propertyFeatures" id="propertyRowREN004930163propertyFeatures">
# <div class="ui-column" style="float: left; width: 200px; height: 110px;"><div class="columnGroup propFeatureHeader">FEATURES:</div><div class="columnGroup">
# <span class="featureGroup">Architecture Style: </span><span class="featureName">Other</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Lot Size: </span><span class="featureName">0.31 Acres</span>
# </div><div class="columnGroup">
# <span class="featureGroup">Roof Type: </span><span class="featureName">Unknown</span>
# </div></div></div>
# </div>
# </div>]
